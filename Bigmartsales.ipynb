# %%
import numpy as np
import pandas as pd
train = pd.read_csv('/content/train_v9rqX0R.csv')  #Both files have been added directly from 'BigMart Sales Data' dataset
test = pd.read_csv('/content/test_AbJTz2l.csv')
print(train.shape)
print(test.shape)
# Out:
# (8523, 12)
# (5681, 11)

# %%
print(train.info())    #Checking datatypes and missing values
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB
# None

# %%
print(train.isna().sum())    #Checking  number of missing values for each column
print(test.isna().sum())
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
train.columns = train.columns.str.lower()    #Changing column names to lowercase so I don't have to worry about case
test.columns = test.columns.str.lower()

# %%
train.head()
# Out:
#   item_identifier  item_weight item_fat_content  item_visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                item_type  item_mrp outlet_identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    outlet_establishment_year outlet_size outlet_location_type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          outlet_type  item_outlet_sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
#Imputing missing values using the fillna method
train.item_weight.fillna(train.item_weight.mean(), inplace = True)   #Imputing missing item_weight by mean item_weight (numerical data)
train.outlet_size.fillna(train.outlet_size.mode()[0], inplace=True)  #Imputing missing outlet_size by its mode (categorical data)
# Out:
# <ipython-input-11-03078cfcfbe1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train.item_weight.fillna(train.item_weight.mean(), inplace = True)   #Imputing missing item_weight by mean item_weight (numerical data)
# <ipython-input-11-03078cfcfbe1>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train.outlet_size.fillna(train.outlet_size.mode()[0], inplace=True)  #Imputing missing outlet_size by its mode (categorical data)

# %%
test.item_weight.fillna(test.item_weight.mean(), inplace = True)
test.outlet_size.fillna(test.outlet_size.mode()[0], inplace=True)
# Out:
# <ipython-input-12-c46b19ce2bdf>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test.item_weight.fillna(test.item_weight.mean(), inplace = True)
# <ipython-input-12-c46b19ce2bdf>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test.outlet_size.fillna(test.outlet_size.mode()[0], inplace=True)

# %%
print(train.isna().sum())    #Checking  number of missing values for each column
print(test.isna().sum())
# Out:
# item_identifier              0
# item_weight                  0
# item_fat_content             0
# item_visibility              0
# item_type                    0
# item_mrp                     0
# outlet_identifier            0
# outlet_establishment_year    0
# outlet_size                  0
# outlet_location_type         0
# outlet_type                  0
# item_outlet_sales            0
# dtype: int64
# item_identifier              0
# item_weight                  0
# item_fat_content             0
# item_visibility              0
# item_type                    0
# item_mrp                     0
# outlet_identifier            0
# outlet_establishment_year    0
# outlet_size                  0
# outlet_location_type         0
# outlet_type                  0
# dtype: int64

# %%
train.columns
# Out:
# Index(['item_identifier', 'item_weight', 'item_fat_content', 'item_visibility',
#        'item_type', 'item_mrp', 'outlet_identifier',
#        'outlet_establishment_year', 'outlet_size', 'outlet_location_type',
#        'outlet_type', 'item_outlet_sales'],
#       dtype='object')

# %%
train.drop(train[['item_identifier','outlet_identifier','outlet_establishment_year']], inplace=True,  axis=1)
test.drop(test[['item_identifier','outlet_identifier','outlet_establishment_year']], inplace=True,  axis=1)

# %%
print(train.columns)
print(test.columns)
# Out:
# Index(['item_weight', 'item_fat_content', 'item_visibility', 'item_type',
#        'item_mrp', 'outlet_size', 'outlet_location_type', 'outlet_type',
#        'item_outlet_sales'],
#       dtype='object')
# Index(['item_weight', 'item_fat_content', 'item_visibility', 'item_type',
#        'item_mrp', 'outlet_size', 'outlet_location_type', 'outlet_type'],
#       dtype='object')

# %%
pd.get_dummies(train)
#item_fat_content column has duplicate values - LF, Low Fat and low fat; Regular and reg
# Out:
#       item_weight  item_visibility  item_mrp  item_outlet_sales  \
# 0           9.300         0.016047  249.8092          3735.1380
# 1           5.920         0.019278   48.2692           443.4228
# 2          17.500         0.016760  141.6180          2097.2700
# 3          19.200         0.000000  182.0950           732.3800
# 4           8.930         0.000000   53.8614           994.7052
# ...           ...              ...       ...                ...
# 8518        6.865         0.056783  214.5218          2778.3834
# 8519        8.380         0.046982  108.1570           549.2850
# 8520       10.600         0.035186   85.1224          1193.1136
# 8521        7.210         0.145221  103.1332          1845.5976
# 8522       14.800         0.044878   75.4670           765.6700
#
#       item_fat_content_LF  item_fat_content_Low Fat  item_fat_content_Regular  \
# 0                   False                      True                     False
# 1                   False                     False                      True
# 2                   False                      True                     False
# 3                   False                     False                      True
# 4                   False                      True                     False
# ...                   ...                       ...                       ...
# 8518                False                      True                     False
# 8519                False                     False                      True
# 8520                False                      True                     False
# 8521                False                     False                      True
# 8522                False                      True                     False
#
#       item_fat_content_low fat  item_fat_content_reg  item_type_Baking Goods  \
# 0                        False                 False                   False
# 1                        False                 False                   False
# 2                        False                 False                   False
# 3                        False                 False                   False
# 4                        False                 False                   False
# ...                        ...                   ...                     ...
# 8518                     False                 False                   False
# 8519                     False                 False                    True
# 8520                     False                 False                   False
# 8521                     False                 False                   False
# 8522                     False                 False                   False
#
#       ...  outlet_size_High  outlet_size_Medium  outlet_size_Small  \
# 0     ...             False                True              False
# 1     ...             False                True              False
# 2     ...             False                True              False
# 3     ...             False                True              False
# 4     ...              True               False              False
# ...   ...               ...                 ...                ...
# 8518  ...              True               False              False
# 8519  ...             False                True              False
# 8520  ...             False               False               True
# 8521  ...             False                True              False
# 8522  ...             False               False               True
#
#       outlet_location_type_Tier 1  outlet_location_type_Tier 2  \
# 0                            True                        False
# 1                           False                        False
# 2                            True                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 8518                        False                        False
# 8519                        False                         True
# 8520                        False                         True
# 8521                        False                        False
# 8522                         True                        False
#
#       outlet_location_type_Tier 3  outlet_type_Grocery Store  \
# 0                           False                      False
# 1                            True                      False
# 2                           False                      False
# 3                            True                       True
# 4                            True                      False
# ...                           ...                        ...
# 8518                         True                      False
# 8519                        False                      False
# 8520                        False                      False
# 8521                         True                      False
# 8522                        False                      False
#
#       outlet_type_Supermarket Type1  outlet_type_Supermarket Type2  \
# 0                              True                          False
# 1                             False                           True
# 2                              True                          False
# 3                             False                          False
# 4                              True                          False
# ...                             ...                            ...
# 8518                           True                          False
# 8519                           True                          False
# 8520                           True                          False
# 8521                          False                           True
# 8522                           True                          False
#
#       outlet_type_Supermarket Type3
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
# ...                             ...
# 8518                          False
# 8519                          False
# 8520                          False
# 8521                          False
# 8522                          False
#
# [8523 rows x 35 columns]

# %%
train.item_fat_content.replace(['LF','low fat','reg'],['Low Fat','Low Fat','Regular'], inplace=True)   #Relpacing duplicate va;ues
test.item_fat_content.replace(['LF','low fat','reg'],['Low Fat','Low Fat','Regular'], inplace=True)
# Out:
# <ipython-input-18-ca91320d4dcf>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train.item_fat_content.replace(['LF','low fat','reg'],['Low Fat','Low Fat','Regular'], inplace=True)   #Relpacing duplicate va;ues
# <ipython-input-18-ca91320d4dcf>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test.item_fat_content.replace(['LF','low fat','reg'],['Low Fat','Low Fat','Regular'], inplace=True)

# %%
print(train.item_type.unique())                #Checking other duplicate values
print(train.outlet_size.unique())
print(train.outlet_location_type.unique())
print(train.outlet_type.unique())
# Out:
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# ['Medium' 'High' 'Small']
# ['Tier 1' 'Tier 3' 'Tier 2']
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
train = pd.get_dummies(train)      #Dummifying categorical variables
test = pd.get_dummies(test)

# %%
train_x = train.drop(train[['item_outlet_sales']], axis=1)   #Separating dependent and independent variables of the train dataset
train_y = train['item_outlet_sales']

# %%
def scaler(data):      #Creating a MinMax Scaler function
    for col in data:
        if data[col].dtype != bool: #Check if the column is not boolean
            # Convert to numpy.float64
            data[col] = data[col].astype(np.float64)
            data[col] = (data[col] - min(data[col])) / (max(data[col]) - min(data[col]))
    return data

# %%
train_x = scaler(train_x)      #Normalizing the train_x dataframe
test = scaler(test)       #Normalizing the test dataframe
train.head()
# Out:
#    item_weight  item_visibility  item_mrp  item_outlet_sales  \
# 0         9.30         0.016047  249.8092          3735.1380
# 1         5.92         0.019278   48.2692           443.4228
# 2        17.50         0.016760  141.6180          2097.2700
# 3        19.20         0.000000  182.0950           732.3800
# 4         8.93         0.000000   53.8614           994.7052
#
#    item_fat_content_Low Fat  item_fat_content_Regular  item_type_Baking Goods  \
# 0                      True                     False                   False
# 1                     False                      True                   False
# 2                      True                     False                   False
# 3                     False                      True                   False
# 4                      True                     False                   False
#
#    item_type_Breads  item_type_Breakfast  item_type_Canned  ...  \
# 0             False                False             False  ...
# 1             False                False             False  ...
# 2             False                False             False  ...
# 3             False                False             False  ...
# 4             False                False             False  ...
#
#    outlet_size_High  outlet_size_Medium  outlet_size_Small  \
# 0             False                True              False
# 1             False                True              False
# 2             False                True              False
# 3             False                True              False
# 4              True               False              False
#
#    outlet_location_type_Tier 1  outlet_location_type_Tier 2  \
# 0                         True                        False
# 1                        False                        False
# 2                         True                        False
# 3                        False                        False
# 4                        False                        False
#
#    outlet_location_type_Tier 3  outlet_type_Grocery Store  \
# 0                        False                      False
# 1                         True                      False
# 2                        False                      False
# 3                         True                       True
# 4                         True                      False
#
#    outlet_type_Supermarket Type1  outlet_type_Supermarket Type2  \
# 0                           True                          False
# 1                          False                           True
# 2                           True                          False
# 3                          False                          False
# 4                           True                          False
#
#    outlet_type_Supermarket Type3
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
# [5 rows x 32 columns]

# %%
test.head()
# Out:
#    item_weight  item_visibility  item_mrp  item_fat_content_Low Fat  \
# 0     0.964275         0.023374  0.323413                      True
# 1     0.222983         0.118737  0.235849                     False
# 2     0.598095         0.307674  0.894140                      True
# 3     0.164335         0.047548  0.524488                      True
# 4     0.484706         0.366458  0.862069                     False
#
#    item_fat_content_Regular  item_type_Baking Goods  item_type_Breads  \
# 0                     False                   False             False
# 1                      True                   False             False
# 2                     False                   False             False
# 3                     False                   False             False
# 4                      True                   False             False
#
#    item_type_Breakfast  item_type_Canned  item_type_Dairy  ...  \
# 0                False             False            False  ...
# 1                False             False             True  ...
# 2                False             False            False  ...
# 3                False             False            False  ...
# 4                False             False             True  ...
#
#    outlet_size_High  outlet_size_Medium  outlet_size_Small  \
# 0             False                True              False
# 1             False                True              False
# 2             False                True              False
# 3             False                True              False
# 4             False                True              False
#
#    outlet_location_type_Tier 1  outlet_location_type_Tier 2  \
# 0                         True                        False
# 1                        False                         True
# 2                        False                        False
# 3                        False                         True
# 4                        False                        False
#
#    outlet_location_type_Tier 3  outlet_type_Grocery Store  \
# 0                        False                      False
# 1                        False                      False
# 2                         True                       True
# 3                        False                      False
# 4                         True                      False
#
#    outlet_type_Supermarket Type1  outlet_type_Supermarket Type2  \
# 0                           True                          False
# 1                           True                          False
# 2                          False                          False
# 3                           True                          False
# 4                          False                          False
#
#    outlet_type_Supermarket Type3
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                           True
#
# [5 rows x 31 columns]

# %%
train_array = np.array(train_x)
test_array = np.array(test)

# %%
#Calculating distance between test and train row using (train - test)^2 = train^2 + test^2 - 2*train*test
def euclidian_distance(trainset, testset):
    m = trainset.shape[0]      #Assigning variables for number of rows of train_x and test_x datasets
    n = testset.shape[0]

    trainset_dots = (trainset * trainset).sum(axis=1).reshape(m,1) * np.ones(shape=(1,n))

    testset_dots = (testset * testset).sum(axis=1) * np.ones(shape=(m,1))

    test_train_dots = -2 * trainset.dot(testset.T)

    # Convert to numpy.float64 before applying np.sqrt
    distance = np.sqrt((trainset_dots + testset_dots + test_train_dots).astype(np.float64))

    return distance

# %%
distance_array = euclidian_distance(train_array, test_array)

# %%
distance_array.shape          #Shape should be equal to (number of rows of train, number of rows of test)
# Out:
# (8523, 5681)

# %%
def Knn_regression(distance_data, k):
    nn_indices = np.argsort(distance_data, axis=0)[:k:]    #Getting the corresponding indices of the elements of sorted distance matrix in original distance matrix
    nn_indices = pd.DataFrame(nn_indices)

    pred = pd.DataFrame(np.zeros((len(test),1)))                        #Creating a zero matrix of the same size as test_y

    # Use .items() instead of .iteritems() to iterate over DataFrame columns
    for i, j in nn_indices.items():             #Calculating sum of k-nearest neighbors and storing it in pred dataframe
        sum = 0.0
        for x in j:
            sum = sum + train_y.iloc[x]
        a = np.array(sum/k)
        pred.iloc[i,0] = a

    return pred

# %%
predicted = Knn_regression(distance_array, 9)
predicted.shape
# Out:
# (5681, 1)

# %%
predicted = pd.DataFrame(predicted)
predicted
# Out:
#                 0
# 0     2449.922067
# 1     1119.875600
# 2      345.550200
# 3     1837.164133
# 4     6029.262867
# ...           ...
# 5676  2057.765867
# 5677  2053.697089
# 5678  1911.141911
# 5679  3044.111578
# 5680  1515.212844
#
# [5681 rows x 1 columns]

# %%
dummy=pd.read_csv('/content/test_AbJTz2l.csv')

# %%
test_predictions = pd.DataFrame({
    'Item_Identifier': dummy.Item_Identifier,
    'Outlet_Identifier' : dummy.Outlet_Identifier,
    'Item_Outlet_Sales' : predicted[0] # Extract the first (and only) column as a Series
}, columns = ['Item_Identifier', 'Outlet_Identifier', 'Item_Outlet_Sales'])

# %%
test_predictions
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049        2449.922067
# 1              FDW14            OUT017        1119.875600
# 2              NCN55            OUT010         345.550200
# 3              FDQ58            OUT017        1837.164133
# 4              FDY38            OUT027        6029.262867
# ...              ...               ...                ...
# 5676           FDB58            OUT046        2057.765867
# 5677           FDD47            OUT018        2053.697089
# 5678           NCO17            OUT045        1911.141911
# 5679           FDJ26            OUT017        3044.111578
# 5680           FDU37            OUT045        1515.212844
#
# [5681 rows x 3 columns]

# %%
test_predictions.to_csv('test_predictions.csv', index=False)
